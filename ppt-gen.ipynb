# %% [markdown]
# # Generate a PowerPoint With an LLM
#
# This is the notebook related to the Medium article *[How to Generate a PowerPoint With an LLM](https://medium.com/@matteo28/how-to-generate-a-powerpoint-with-an-llm-3b0448a48125)*.
#
# In this notebook there is code to be able to create a powerpoint using the Gemini to take advantage of the Gemini-2.0 templates for text generation and imaged-3 for image generation.

# %%
# !pip install llama-index-llms-google-genai llama-index
# Out:
# Requirement already satisfied: llama-index-llms-google-genai in /opt/conda/lib/python3.10/site-packages (0.1.13)
# Requirement already satisfied: llama-index in /opt/conda/lib/python3.10/site-packages (0.12.37)
# Requirement already satisfied: google-genai>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-llms-google-genai) (1.16.1)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.36 in /opt/conda/lib/python3.10/site-packages (from llama-index-llms-google-genai) (0.12.37)
# Requirement already satisfied: pillow>=10.2.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-llms-google-genai) (11.2.1)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.4.8)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.6.11)
# Requirement already satisfied: llama-index-llms-openai<0.4,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.3.44)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /opt/conda/lib/python3.10/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai) (2.40.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai) (2.11.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai) (14.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /opt/conda/lib/python3.10/site-packages (from google-genai>=1.4.0->llama-index-llms-google-genai) (4.13.2)
# Requirement already satisfied: openai>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.82.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (3.11.18)
# Requirement already satisfied: aiosqlite in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (2.1.2)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (2024.12.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (3.4.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.26.4)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (6.0.2)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (2.0.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (4.67.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.17.2)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in /opt/conda/lib/python3.10/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.22)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (4.13.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.1.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (5.5.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.23)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/jupyter/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.20.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai>=1.4.0->llama-index-llms-google-genai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai>=1.4.0->llama-index-llms-google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai>=1.4.0->llama-index-llms-google-genai) (1.3.1)
# Requirement already satisfied: griffe in /opt/conda/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.7.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (3.1.6)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (4.3.8)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai>=1.4.0->llama-index-llms-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai>=1.4.0->llama-index-llms-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai>=1.4.0->llama-index-llms-google-genai) (4.9.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai>=1.4.0->llama-index-llms-google-genai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai>=1.4.0->llama-index-llms-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai>=1.4.0->llama-index-llms-google-genai) (0.16.0)
# Requirement already satisfied: llama-cloud-services>=0.6.23 in /opt/conda/lib/python3.10/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.23)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (0.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai>=1.4.0->llama-index-llms-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai>=1.4.0->llama-index-llms-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai>=1.4.0->llama-index-llms-google-genai) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai>=1.4.0->llama-index-llms-google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai>=1.4.0->llama-index-llms-google-genai) (2.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (3.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from llama-cloud-services>=0.6.23->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (24.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai>=1.4.0->llama-index-llms-google-genai) (0.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (1.17.0)
# Requirement already satisfied: colorama>=0.4 in /opt/conda/lib/python3.10/site-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index-llms-google-genai) (3.0.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: llama-index in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.12.37)
# Requirement already satisfied: google-genai in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.16.1)
# Requirement already satisfied: langchain-core in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.3.61)
# Requirement already satisfied: langchain-google-vertexai in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2.0.24)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: python-pptx in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.36 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.12.37)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.6.11)
# Requirement already satisfied: llama-index-llms-openai<0.4,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.3.44)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.4.7)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /opt/conda/lib/python3.10/site-packages (from llama-index->-r requirements.txt (line 1)) (3.9.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 2)) (2.40.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 2)) (2.11.4)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 2)) (14.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /opt/conda/lib/python3.10/site-packages (from google-genai->-r requirements.txt (line 2)) (4.13.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /opt/conda/lib/python3.10/site-packages (from langchain-core->-r requirements.txt (line 3)) (0.3.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain-core->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain-core->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/lib/python3.10/site-packages (from langchain-core->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: bottleneck<2.0.0,>=1.4.2 in /home/jupyter/.local/lib/python3.10/site-packages (from langchain-google-vertexai->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.92.0 in /home/jupyter/.local/lib/python3.10/site-packages (from langchain-google-vertexai->-r requirements.txt (line 4)) (1.94.0)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from langchain-google-vertexai->-r requirements.txt (line 4)) (2.19.0)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from langchain-google-vertexai->-r requirements.txt (line 4)) (0.4.0)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.6 in /home/jupyter/.local/lib/python3.10/site-packages (from langchain-google-vertexai->-r requirements.txt (line 4)) (2.10.2)
# Requirement already satisfied: pyarrow<20.0.0,>=19.0.1 in /opt/conda/lib/python3.10/site-packages (from langchain-google-vertexai->-r requirements.txt (line 4)) (19.0.1)
# Requirement already satisfied: validators<1,>=0.22.0 in /home/jupyter/.local/lib/python3.10/site-packages (from langchain-google-vertexai->-r requirements.txt (line 4)) (0.35.0)
# Requirement already satisfied: Pillow>=3.3.2 in /opt/conda/lib/python3.10/site-packages (from python-pptx->-r requirements.txt (line 6)) (11.2.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from python-pptx->-r requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: lxml>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from python-pptx->-r requirements.txt (line 6)) (5.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->-r requirements.txt (line 7)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->-r requirements.txt (line 7)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->-r requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->-r requirements.txt (line 7)) (2025.4.26)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bottleneck<2.0.0,>=1.4.2->langchain-google-vertexai->-r requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai->-r requirements.txt (line 2)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai->-r requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai->-r requirements.txt (line 2)) (4.9.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (2.24.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (5.29.4)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: docstring-parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (0.16)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai->-r requirements.txt (line 4)) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai->-r requirements.txt (line 4)) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.126->langchain-core->-r requirements.txt (line 3)) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.126->langchain-core->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.126->langchain-core->-r requirements.txt (line 3)) (0.23.0)
# Requirement already satisfied: openai>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (1.82.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (3.11.18)
# Requirement already satisfied: aiosqlite in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (2024.12.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (2.0.37)
# Requirement already satisfied: tiktoken>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in /opt/conda/lib/python3.10/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index->-r requirements.txt (line 1)) (0.1.22)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (4.13.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index->-r requirements.txt (line 1)) (0.6.23)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index->-r requirements.txt (line 1)) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai->-r requirements.txt (line 2)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/jupyter/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.20.0)
# Requirement already satisfied: griffe in /opt/conda/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (4.3.8)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (2.7)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (1.71.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: llama-cloud-services>=0.6.23 in /opt/conda/lib/python3.10/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index->-r requirements.txt (line 1)) (0.6.23)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (3.26.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.92.0->langchain-google-vertexai->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: colorama>=0.4 in /opt/conda/lib/python3.10/site-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index->-r requirements.txt (line 1)) (3.0.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import re

PROJECT_ID = !(gcloud config get-value core/project)
PROJECT_ID = PROJECT_ID[0]

SVC_ACC = !(gcloud config get-value core/account)
SVC_ACC = SVC_ACC[0]

PROJECT_NUMBER=str(re.search(r'\d+', SVC_ACC).group())

LOCATION="us-central1"

FOLDER_NAME="."

# %%
import requests
import json
import os
import re
from llama_index.core import PromptTemplate


from llama_index.llms.google_genai import GoogleGenAI

llm = GoogleGenAI(
    model="gemini-2.0-flash",
    vertexai_config={"project": PROJECT_ID, "location": LOCATION},
)


from pptx import Presentation
from config import Config

# %% [markdown]
# ## Load template

# %%
template_path = os.path.join(Config.TEMPLATES_PATH, 'basic_template.pptx')
prs = Presentation(template_path)

# %%
slide_structures = []

# Iterate through each slide in the presentation
for slide in prs.slides:
    structure = {"placeholders": []}
    
    # Iterate through each shape in the slide
    for shape in slide.shapes:
        if shape.is_placeholder:
            
            # Create a dictionary to store placeholder details
            placeholder = {
                "type": shape.placeholder_format.type,
                "idx": shape.placeholder_format.idx,
                "has_text_frame": shape.has_text_frame,
                "name": shape.name,
            }
            # Check if the placeholder contains a table
            if shape.has_table:
                placeholder["has_table"] = True
                # Extract the table structure as a list of rows with cell texts
                placeholder["table_structure"] = [
                    [cell.text for cell in row.cells] for row in shape.table.rows
                ]
            else:
                placeholder["has_table"] = False
            
            # Check if the placeholder is an image placeholder
            if shape.placeholder_format.type == 18:
                placeholder["has_image"] = True
                placeholder["image_description"] = ""
            else:
                placeholder["has_image"] = False

            # Append the placeholder information to the structure
            structure["placeholders"].append(placeholder)
            
    # Append the slide structure to the list of all slide structures
    slide_structures.append(structure)

# Convert the structure list to a JSON string for better readability
slide_structures_str = json.dumps(slide_structures, indent=4)

# %%
import pprint
pprint.pprint(slide_structures_str)
# Out:
# ('[\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 15,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 18,\n'
#  '                "idx": 14,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Picture Placeholder 17",\n'
#  '                "has_table": false,\n'
#  '                "has_image": true,\n'
#  '                "image_description": ""\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 6",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 18,\n'
#  '                "idx": 13,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Picture Placeholder 8",\n'
#  '                "has_table": false,\n'
#  '                "has_image": true,\n'
#  '                "image_description": ""\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 6",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 4,\n'
#  '                "idx": 1,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Subtitle 7",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 18,\n'
#  '                "idx": 13,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Picture Placeholder 8",\n'
#  '                "has_table": false,\n'
#  '                "has_image": true,\n'
#  '                "image_description": ""\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 6",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Subtitle 7",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 12,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 11",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 13,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 12",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 1,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 13,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 3",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 18,\n'
#  '                "idx": 14,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Picture Placeholder 9",\n'
#  '                "has_table": false,\n'
#  '                "has_image": true,\n'
#  '                "image_description": ""\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 17",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 12,\n'
#  '                "idx": 11,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Content Placeholder 18",\n'
#  '                "has_table": true,\n'
#  '                "table_structure": [\n'
#  '                    [\n'
#  '                        "Metric",\n'
#  '                        "Measurement",\n'
#  '                        "Target",\n'
#  '                        "Actual"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Audience attendance",\n'
#  '                        "# of attendees",\n'
#  '                        "150",\n'
#  '                        "120"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Engagement duration",\n'
#  '                        "Minutes",\n'
#  '                        "60",\n'
#  '                        "75"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Q&A interaction",\n'
#  '                        "# of questions",\n'
#  '                        "10",\n'
#  '                        "15"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Positive feedback",\n'
#  '                        "Percentage (%)",\n'
#  '                        "90",\n'
#  '                        "95"\n'
#  '                    ]\n'
#  '                ],\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 11,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 3",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 12,\n'
#  '                "idx": 10,\n'
#  '                "has_text_frame": false,\n'
#  '                "name": "Content Placeholder 3",\n'
#  '                "has_table": true,\n'
#  '                "table_structure": [\n'
#  '                    [\n'
#  '                        "Impact factor",\n'
#  '                        "Measurement",\n'
#  '                        "Target",\n'
#  '                        "Achieved"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Audience interaction",\n'
#  '                        "Percentage (%)",\n'
#  '                        "85",\n'
#  '                        "88"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Knowledge retention",\n'
#  '                        "Percentage (%)",\n'
#  '                        "75",\n'
#  '                        "80"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Post-presentation surveys",\n'
#  '                        "Average rating",\n'
#  '                        "4.2",\n'
#  '                        "4.5"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Referral rate",\n'
#  '                        "Percentage (%)",\n'
#  '                        "10",\n'
#  '                        "12"\n'
#  '                    ],\n'
#  '                    [\n'
#  '                        "Collaboration opportunities",\n'
#  '                        "# of opportunities",\n'
#  '                        "8",\n'
#  '                        "10"\n'
#  '                    ]\n'
#  '                ],\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    },\n'
#  '    {\n'
#  '        "placeholders": [\n'
#  '            {\n'
#  '                "type": 1,\n'
#  '                "idx": 0,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Title 1",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            },\n'
#  '            {\n'
#  '                "type": 7,\n'
#  '                "idx": 15,\n'
#  '                "has_text_frame": true,\n'
#  '                "name": "Content Placeholder 2",\n'
#  '                "has_table": false,\n'
#  '                "has_image": false\n'
#  '            }\n'
#  '        ]\n'
#  '    }\n'
#  ']')

# %% [markdown]
# ## Prompting

# %%
prompt = """
You are a PowerPoint presentation specialist. You are asked to create content for a presentation about {topic}.
The PowerPoint template has the following structure:

{structure}

You need to generate content that fits into this structure, ensuring that all placeholders are filled appropriately.

For each slide:
1. Provide the title for the slide.
2. Provide the text content for each text placeholder.
3. If a slide contains a table, generate appropriate data to fill it based on the provided context.
4. If a slide contains an image placeholder, describe the type of image that should be included.

Return the structured information *only* as a JSON. Do not include any introductory text or explanations.
"""

prompt_template = PromptTemplate(template=prompt)

test_topic = "Create an example of pitch for a new product named \"Nose\", a platform that helps investors to find the best investment opportunities."

content_prompt = (
    prompt_template.format(topic=test_topic, structure=slide_structures_str)
)

# %% [markdown]
# ## LLM

# %%
from crewai import Agent, Task, Crew, LLM

# llm = LLM(
#               model='vertex_ai/gemini-2.0-flash',
#               vertex_project = PROJECT_ID
#             )

slides_response = llm.complete(content_prompt, True).text

# %%
print(slides_response)
# Out:
# ```json
# [
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "Nose: Your Sixth Sense for Investment Opportunities"
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "The Problem: Finding the Right Investments is Hard"
#       },
#       {
#         "type": 7,
#         "idx": 15,
#         "has_text_frame": true,
#         "name": "Content Placeholder 2",
#         "has_table": false,
#         "has_image": false,
#         "text": "- Information overload: Too much data, not enough insight.\n- Missed opportunities: Hidden gems overlooked due to lack of resources.\n- Time-consuming research: Sifting through countless reports and articles.\n- Inefficient networking: Difficulty connecting with relevant experts and deals."
#       },
#       {
#         "type": 18,
#         "idx": 14,
#         "has_text_frame": false,
#         "name": "Picture Placeholder 17",
#         "has_table": false,
#         "has_image": true,
#         "image_description": "Image depicting a person overwhelmed by data, surrounded by screens and documents."
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 6",
#         "has_table": false,
#         "has_image": false,
#         "text": "Introducing Nose: Your Investment Advantage"
#       },
#       {
#         "type": 18,
#         "idx": 13,
#         "has_text_frame": false,
#         "name": "Picture Placeholder 8",
#         "has_table": false,
#         "has_image": true,
#         "image_description": "Image of a stylized nose sniffing out a shining gold coin or a treasure chest."
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 6",
#         "has_table": false,
#         "has_image": false,
#         "text": "Nose: How It Works"
#       },
#       {
#         "type": 4,
#         "idx": 1,
#         "has_text_frame": true,
#         "name": "Subtitle 7",
#         "has_table": false,
#         "has_image": false,
#         "text": "AI-Powered Investment Discovery"
#       },
#       {
#         "type": 18,
#         "idx": 13,
#         "has_text_frame": false,
#         "name": "Picture Placeholder 8",
#         "has_table": false,
#         "has_image": true,
#         "image_description": "Diagram illustrating the AI process: Data Ingestion -> Analysis & Filtering -> Opportunity Identification -> Personalized Recommendations."
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 2",
#         "has_table": false,
#         "has_image": false,
#         "text": "Key Features"
#       },
#       {
#         "type": 7,
#         "idx": 10,
#         "has_text_frame": true,
#         "name": "Content Placeholder 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "- **AI-Driven Opportunity Discovery:** Identifies promising investments based on your criteria.\n- **Personalized Recommendations:** Tailored suggestions based on your risk profile and investment goals.\n- **Real-Time Data Analysis:** Up-to-the-minute insights on market trends and company performance.\n- **Expert Network Access:** Connect with industry leaders and potential partners.\n- **Due Diligence Tools:** Streamlined access to essential research and analysis resources."
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 6",
#         "has_table": false,
#         "has_image": false,
#         "text": "Benefits for Investors"
#       },
#       {
#         "type": 7,
#         "idx": 10,
#         "has_text_frame": true,
#         "name": "Subtitle 7",
#         "has_table": false,
#         "has_image": false,
#         "text": "- Increased ROI: Discover high-potential investments early.\n- Reduced Risk: Make informed decisions with comprehensive data and analysis.\n- Time Savings: Automate research and focus on strategic decision-making.\n- Competitive Edge: Access exclusive opportunities and insights.\n- Enhanced Networking: Build valuable connections within the investment community."
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "Target Audience"
#       },
#       {
#         "type": 7,
#         "idx": 12,
#         "has_text_frame": true,
#         "name": "Content Placeholder 11",
#         "has_table": false,
#         "has_image": false,
#         "text": "- Angel Investors\n- Venture Capitalists\n- Private Equity Firms"
#       },
#       {
#         "type": 7,
#         "idx": 13,
#         "has_text_frame": true,
#         "name": "Content Placeholder 12",
#         "has_table": false,
#         "has_image": false,
#         "text": "- Family Offices\n- High-Net-Worth Individuals\n- Institutional Investors"
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "Business Model"
#       },
#       {
#         "type": 7,
#         "idx": 1,
#         "has_text_frame": true,
#         "name": "Content Placeholder 2",
#         "has_table": false,
#         "has_image": false,
#         "text": "- **Subscription-based access:** Tiered pricing based on features and data access.\n- **Premium data packages:** Customized data sets and reports for specific industries.\n- **Deal origination fees:** Commission on successful investments facilitated through the platform."
#       },
#       {
#         "type": 7,
#         "idx": 13,
#         "has_text_frame": true,
#         "name": "Content Placeholder 3",
#         "has_table": false,
#         "has_image": false,
#         "text": "- **Partnerships:** Collaboration with financial institutions and investment firms."
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "Competitive Advantage"
#       },
#       {
#         "type": 18,
#         "idx": 14,
#         "has_text_frame": false,
#         "name": "Picture Placeholder 9",
#         "has_table": false,
#         "has_image": true,
#         "image_description": "A graph comparing Nose's AI accuracy and speed to competitors, showing Nose performing significantly better."
#       },
#       {
#         "type": 7,
#         "idx": 10,
#         "has_text_frame": true,
#         "name": "Content Placeholder 2",
#         "has_table": false,
#         "has_image": false,
#         "text": "- **Superior AI algorithms:** More accurate and efficient opportunity identification.\n- **Comprehensive data coverage:** Access to a wider range of data sources.\n- **Personalized user experience:** Tailored recommendations and insights.\n- **Strong network of experts:** Access to valuable industry connections."
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "Pilot Program Results"
#       },
#       {
#         "type": 7,
#         "idx": 10,
#         "has_text_frame": true,
#         "name": "Content Placeholder 17",
#         "has_table": false,
#         "has_image": false,
#         "text": "Our pilot program demonstrated significant positive results, validating the effectiveness of Nose in identifying and facilitating successful investments."
#       },
#       {
#         "type": 12,
#         "idx": 11,
#         "has_text_frame": false,
#         "name": "Content Placeholder 18",
#         "has_table": true,
#         "table_structure": [
#           [
#             "Metric",
#             "Measurement",
#             "Target",
#             "Actual"
#           ],
#           [
#             "Audience attendance",
#             "# of attendees",
#             "150",
#             "165"
#           ],
#           [
#             "Engagement duration",
#             "Minutes",
#             "60",
#             "70"
#           ],
#           [
#             "Q&A interaction",
#             "# of questions",
#             "10",
#             "12"
#           ],
#           [
#             "Positive feedback",
#             "Percentage (%)",
#             "90",
#             "92"
#           ]
#         ],
#         "has_image": false
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "Team"
#       },
#       {
#         "type": 7,
#         "idx": 11,
#         "has_text_frame": true,
#         "name": "Content Placeholder 2",
#         "has_table": false,
#         "has_image": false,
#         "text": "- Experienced team of AI experts, financial analysts, and software engineers.\n- Proven track record in building and scaling successful technology companies."
#       },
#       {
#         "type": 7,
#         "idx": 10,
#         "has_text_frame": true,
#         "name": "Content Placeholder 3",
#         "has_table": false,
#         "has_image": false,
#         "text": "- Passionate about revolutionizing the investment landscape."
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "Investment Highlights"
#       },
#       {
#         "type": 12,
#         "idx": 10,
#         "has_text_frame": false,
#         "name": "Content Placeholder 3",
#         "has_table": true,
#         "table_structure": [
#           [
#             "Impact factor",
#             "Measurement",
#             "Target",
#             "Achieved"
#           ],
#           [
#             "Audience interaction",
#             "Percentage (%)",
#             "85",
#             "87"
#           ],
#           [
#             "Knowledge retention",
#             "Percentage (%)",
#             "75",
#             "78"
#           ],
#           [
#             "Post-presentation surveys",
#             "Average rating",
#             "4.2",
#             "4.3"
#           ],
#           [
#             "Referral rate",
#             "Percentage (%)",
#             "10",
#             "11"
#           ],
#           [
#             "Collaboration opportunities",
#             "# of opportunities",
#             "8",
#             "9"
#           ]
#         ],
#         "has_image": false
#       }
#     ]
#   },
#   {
#     "placeholders": [
#       {
#         "type": 1,
#         "idx": 0,
#         "has_text_frame": true,
#         "name": "Title 1",
#         "has_table": false,
#         "has_image": false,
#         "text": "Thank You. Let's Talk."
#       },
#       {
#         "type": 7,
#         "idx": 15,
#         "has_text_frame": true,
#         "name": "Content Placeholder 2",
#         "has_table": false,
#         "has_image": false,
#         "text": "Contact Information: [Your Name], [Your Email], [Your Phone Number], [Your Website]"
#       }
#     ]
#   }
# ]
# ```

# %%
json_match = re.search(r'```json\s*(.*?)\s*```', slides_response, re.DOTALL)

if json_match:
    json_content = json_match.group(1)
    try:
        slides = json.loads(json_content)
    except json.JSONDecodeError as e:
        raise ValueError(f"JSON parsing error: {str(e)}")
else:
    raise ValueError("The JSON was not found in the model response.")

# %%
pprint.pprint(slides)
# Out:
# [{'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Nose: Your Sixth Sense for Investment '
#                             'Opportunities',
#                     'type': 1}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'The Problem: Finding the Right Investments is '
#                             'Hard',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 15,
#                     'name': 'Content Placeholder 2',
#                     'text': '- Information overload: Too much data, not enough '
#                             'insight.\n'
#                             '- Missed opportunities: Hidden gems overlooked '
#                             'due to lack of resources.\n'
#                             '- Time-consuming research: Sifting through '
#                             'countless reports and articles.\n'
#                             '- Inefficient networking: Difficulty connecting '
#                             'with relevant experts and deals.',
#                     'type': 7},
#                    {'has_image': True,
#                     'has_table': False,
#                     'has_text_frame': False,
#                     'idx': 14,
#                     'image_description': 'Image depicting a person overwhelmed '
#                                          'by data, surrounded by screens and '
#                                          'documents.',
#                     'name': 'Picture Placeholder 17',
#                     'type': 18}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 6',
#                     'text': 'Introducing Nose: Your Investment Advantage',
#                     'type': 1},
#                    {'has_image': True,
#                     'has_table': False,
#                     'has_text_frame': False,
#                     'idx': 13,
#                     'image_description': 'Image of a stylized nose sniffing '
#                                          'out a shining gold coin or a '
#                                          'treasure chest.',
#                     'name': 'Picture Placeholder 8',
#                     'type': 18}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 6',
#                     'text': 'Nose: How It Works',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 1,
#                     'name': 'Subtitle 7',
#                     'text': 'AI-Powered Investment Discovery',
#                     'type': 4},
#                    {'has_image': True,
#                     'has_table': False,
#                     'has_text_frame': False,
#                     'idx': 13,
#                     'image_description': 'Diagram illustrating the AI process: '
#                                          'Data Ingestion -> Analysis & '
#                                          'Filtering -> Opportunity '
#                                          'Identification -> Personalized '
#                                          'Recommendations.',
#                     'name': 'Picture Placeholder 8',
#                     'type': 18}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 2',
#                     'text': 'Key Features',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Content Placeholder 1',
#                     'text': '- **AI-Driven Opportunity Discovery:** Identifies '
#                             'promising investments based on your criteria.\n'
#                             '- **Personalized Recommendations:** Tailored '
#                             'suggestions based on your risk profile and '
#                             'investment goals.\n'
#                             '- **Real-Time Data Analysis:** Up-to-the-minute '
#                             'insights on market trends and company '
#                             'performance.\n'
#                             '- **Expert Network Access:** Connect with '
#                             'industry leaders and potential partners.\n'
#                             '- **Due Diligence Tools:** Streamlined access to '
#                             'essential research and analysis resources.',
#                     'type': 7}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 6',
#                     'text': 'Benefits for Investors',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Subtitle 7',
#                     'text': '- Increased ROI: Discover high-potential '
#                             'investments early.\n'
#                             '- Reduced Risk: Make informed decisions with '
#                             'comprehensive data and analysis.\n'
#                             '- Time Savings: Automate research and focus on '
#                             'strategic decision-making.\n'
#                             '- Competitive Edge: Access exclusive '
#                             'opportunities and insights.\n'
#                             '- Enhanced Networking: Build valuable connections '
#                             'within the investment community.',
#                     'type': 7}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Target Audience',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 12,
#                     'name': 'Content Placeholder 11',
#                     'text': '- Angel Investors\n'
#                             '- Venture Capitalists\n'
#                             '- Private Equity Firms',
#                     'type': 7},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 13,
#                     'name': 'Content Placeholder 12',
#                     'text': '- Family Offices\n'
#                             '- High-Net-Worth Individuals\n'
#                             '- Institutional Investors',
#                     'type': 7}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Business Model',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 1,
#                     'name': 'Content Placeholder 2',
#                     'text': '- **Subscription-based access:** Tiered pricing '
#                             'based on features and data access.\n'
#                             '- **Premium data packages:** Customized data sets '
#                             'and reports for specific industries.\n'
#                             '- **Deal origination fees:** Commission on '
#                             'successful investments facilitated through the '
#                             'platform.',
#                     'type': 7},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 13,
#                     'name': 'Content Placeholder 3',
#                     'text': '- **Partnerships:** Collaboration with financial '
#                             'institutions and investment firms.',
#                     'type': 7}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Competitive Advantage',
#                     'type': 1},
#                    {'has_image': True,
#                     'has_table': False,
#                     'has_text_frame': False,
#                     'idx': 14,
#                     'image_description': "A graph comparing Nose's AI accuracy "
#                                          'and speed to competitors, showing '
#                                          'Nose performing significantly '
#                                          'better.',
#                     'name': 'Picture Placeholder 9',
#                     'type': 18},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Content Placeholder 2',
#                     'text': '- **Superior AI algorithms:** More accurate and '
#                             'efficient opportunity identification.\n'
#                             '- **Comprehensive data coverage:** Access to a '
#                             'wider range of data sources.\n'
#                             '- **Personalized user experience:** Tailored '
#                             'recommendations and insights.\n'
#                             '- **Strong network of experts:** Access to '
#                             'valuable industry connections.',
#                     'type': 7}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Pilot Program Results',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Content Placeholder 17',
#                     'text': 'Our pilot program demonstrated significant '
#                             'positive results, validating the effectiveness of '
#                             'Nose in identifying and facilitating successful '
#                             'investments.',
#                     'type': 7},
#                    {'has_image': False,
#                     'has_table': True,
#                     'has_text_frame': False,
#                     'idx': 11,
#                     'name': 'Content Placeholder 18',
#                     'table_structure': [['Metric',
#                                          'Measurement',
#                                          'Target',
#                                          'Actual'],
#                                         ['Audience attendance',
#                                          '# of attendees',
#                                          '150',
#                                          '165'],
#                                         ['Engagement duration',
#                                          'Minutes',
#                                          '60',
#                                          '70'],
#                                         ['Q&A interaction',
#                                          '# of questions',
#                                          '10',
#                                          '12'],
#                                         ['Positive feedback',
#                                          'Percentage (%)',
#                                          '90',
#                                          '92']],
#                     'type': 12}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Team',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 11,
#                     'name': 'Content Placeholder 2',
#                     'text': '- Experienced team of AI experts, financial '
#                             'analysts, and software engineers.\n'
#                             '- Proven track record in building and scaling '
#                             'successful technology companies.',
#                     'type': 7},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 10,
#                     'name': 'Content Placeholder 3',
#                     'text': '- Passionate about revolutionizing the investment '
#                             'landscape.',
#                     'type': 7}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': 'Investment Highlights',
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': True,
#                     'has_text_frame': False,
#                     'idx': 10,
#                     'name': 'Content Placeholder 3',
#                     'table_structure': [['Impact factor',
#                                          'Measurement',
#                                          'Target',
#                                          'Achieved'],
#                                         ['Audience interaction',
#                                          'Percentage (%)',
#                                          '85',
#                                          '87'],
#                                         ['Knowledge retention',
#                                          'Percentage (%)',
#                                          '75',
#                                          '78'],
#                                         ['Post-presentation surveys',
#                                          'Average rating',
#                                          '4.2',
#                                          '4.3'],
#                                         ['Referral rate',
#                                          'Percentage (%)',
#                                          '10',
#                                          '11'],
#                                         ['Collaboration opportunities',
#                                          '# of opportunities',
#                                          '8',
#                                          '9']],
#                     'type': 12}]},
#  {'placeholders': [{'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 0,
#                     'name': 'Title 1',
#                     'text': "Thank You. Let's Talk.",
#                     'type': 1},
#                    {'has_image': False,
#                     'has_table': False,
#                     'has_text_frame': True,
#                     'idx': 15,
#                     'name': 'Content Placeholder 2',
#                     'text': 'Contact Information: [Your Name], [Your Email], '
#                             '[Your Phone Number], [Your Website]',
#                     'type': 7}]}]

# %%
from google import genai

def generate_image(description):
    response = genai.images.generate(
        model="imagen-e-3",
        prompt=description,
        n=1,
        response_format="url",
    )
    image_url = response.data[0].url
    image_data = requests.get(image_url).content
    return image_data

# %%
def populate_slide(slide, slide_data):
    # Get the list of placeholders
    placeholders = slide_data.get("placeholders", [])

    # Popolare i placeholders di testo
    for placeholder in placeholders:
        for shape in slide.shapes:
            if shape.is_placeholder and placeholder.get("name") in shape.name:
                if placeholder.get("text") and shape.has_text_frame:
                    shape.text = placeholder["text"]

    # Populate text placeholders
    for placeholder in placeholders:
        if placeholder.get("image_description"):
            # image_data = generate_image(placeholder["image_description"])
            img_path = "temp_image.png"
            # with open(img_path, "wb") as img_file:
            #     img_file.write(image_data)
            # for shape in slide.shapes:
            #     if shape.is_placeholder and shape.placeholder_format.type == 18:
            #         slide.shapes._spTree.remove(shape._element)
            #         slide.shapes.add_picture(img_path, shape.left, shape.top, shape.width, shape.height)
            #         break

    # Populate the tables
    for placeholder in placeholders:
        table_data = placeholder.get("table_structure")
        if table_data:
            for shape in slide.shapes:
                if shape.has_table:
                    table = shape.table
                    for i, row_data in enumerate(table_data):
                        for j, cell_text in enumerate(row_data):
                            table.cell(i, j).text = cell_text
                    break

# %%
for i, slide_data in enumerate(slides):
    if i < len(prs.slides):
        populate_slide(prs.slides[i], slide_data)

# %%
save_path = os.path.join(Config.POWERPOINTS_PATH, "output2.pptx")
prs.save(save_path)

# %%
save_path
# Out:
# '/home/jupyter/GenAI9/llm-powerpoint/powerpoints/output2.pptx'
